# %% [markdown]
# <a href="https://colab.research.google.com/github/Nguyenthithu035/-0.7/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10주차 실습: 나만의 맞춤형 한국어 플래시 카드 봇 만들기
#
# **[실습 목표]**
# Gemini에게 물어서 만든 단어장(`.csv`) 파일을 코랩에 업로드하고, 아래 준비된 뼈대(Skeleton) 코드의 빈칸을 AI(Gemini)와 협업하여 채워 나만의 퀴즈 봇을 완성합니다.
#
# ---
# ### 💡 왕초보를 위한 구글 코랩(Colab) 사용법
# 코랩은 **'셀(Cell)'** 단위로 코드를 작성하고 실행합니다. 아래에 있는 회색 박스들이 바로 코드를 입력하는 '코드 셀'입니다.
# 코드를 실행하려면 다음 방법 중 하나를 사용하세요:
# 1. **마우스 사용:** 코드 셀 왼쪽 상단에 나타나는 **동그란 실행(▶️) 버튼**을 클릭합니다.
# 2. **키보드 단축키 (추천):** 셀 안을 클릭한 뒤, **`Shift + Enter`**를 누르면 코드가 실행되고 다음 셀로 넘어갑니다. (또는 **`Ctrl + Enter`**를 누르면 코드가 실행되고 현재 셀에 머뭅니다.)

# %% [markdown]
# ## Step 1: 내 단어장 파일(.csv) 업로드 확인
#
# 우리가 만든 파이썬 프로그램이 단어들을 읽어올 수 있도록 파일을 코랩에 올려주어야 합니다.
#
# 1. 화면 왼쪽 가장자리에 있는 **폴더 모양 아이콘(📁)**을 클릭합니다.
# 2. `my_words.csv` 파일이 목록에 잘 보이는지 확인하세요.
# 3. 만약 파일이 없다면, 내 컴퓨터(바탕화면 등)에 있는 `my_words.csv` 파일을 마우스로 끌어서 왼쪽 폴더 창 안에 놓아주세요(드래그 앤 드롭).

# %% [markdown]
# ## Step 2: 파이썬의 '도구함(모듈)' 가져오기
#
# 파이썬에는 모든 기능이 처음부터 다 들어있지 않습니다. 필요한 기능이 담긴 **'도구함(모듈)'**을 먼저 가져와야(import) 코드를 짤 수 있습니다.
#
# * `import csv`: 엑셀이나 콤마(,)로 구분된 CSV 파일을 읽고 쓸 수 있는 도구함을 가져옵니다.
# * `import random`: 제비뽑기처럼 무언가를 무작위로(랜덤하게) 골라주는 도구함을 가져옵니다.
#
# 아래 코드 셀을 클릭하고 **`Shift + Enter`**를 눌러 도구함들을 먼저 준비해 주세요.

# %%
import csv      # CSV 파일 처리 도구함 가져오기
import random   # 무작위 추출 도구함 가져오기

# %%
import csv

# Dữ liệu từ vựng tiếng Hàn và tiếng Việt
data = [
    ['한국어', '베트남어'],
    ['안녕하세요', 'Xin chào'],
    ['감사합니다', 'Cảm ơn'],
    ['네', 'Vâng / Dạ'],
    ['아니요', 'Không'],
    ['죄송합니다', 'Xin lỗi'],
    ['잠시만요', 'Khoan đã / Chờ một chút'],
    ['사랑해요', 'Anh yêu em / Em yêu anh'],
    ['좋아해요', 'Tôi thích bạn'],
    ['배고파요', 'Tôi đói bụng'],
    ['목말라요', 'Tôi khát nước'],
    ['화장실', 'Nhà vệ sinh'],
    ['물', 'Nước'],
    ['커피', 'Cà phê'],
    ['밥', 'Cơm'],
    ['빵', 'Bánh mì'],
    ['김치', 'Kim chi'],
    ['비빔밥', 'Cơm trộn'],
    ['맛있어요', 'Ngon'],
    ['맛없어요', 'Dở'],
    ['얼마예요?', 'Bao nhiêu tiền?'],
    ['여기요', 'Ở đây (Gọi phục vụ)'],
    ['저기요', 'Ở đằng kia'],
    ['이거', 'Cái này'],
    ['저거', 'Cái kia'],
    ['어디', 'Ở đâu'],
    ['언제', 'Khi nào'],
    ['무엇', 'Cái gì'],
    ['누구', 'Ai'],
    ['왜', 'Tại sao'],
    ['어떻게', 'Làm thế nào'],
    ['예쁘다', 'Đẹp'],
    ['귀엽다', 'Dễ thương'],
    ['덥다', 'Nóng'],
    ['춥다', 'Lạnh'],
    ['좋다', 'Tốt / Thích'],
    ['싫다', 'Không thích / Ghét'],
    ['크다', 'To / Lớn'],
    ['작다', 'Nhỏ'],
    ['많다', 'Nhiều'],
    ['적다', 'Ít'],
    ['있다', 'Có'],
    ['없다', 'Không có'],
    ['가다', 'Đi'],
    ['오다', 'Đến'],
    ['먹다', 'Ăn'],
    ['자다', 'Ngủ'],
    ['공부하다', 'Học'],
    ['일하다', 'Làm việc'],
    ['보다', 'Nhìn / Xem'],
    ['듣다', 'Nghe'],
    ['말하다', 'Nói']
]

# Tên tệp CSV
filename = "my_words.csv"

# Ghi dữ liệu vào tệp CSV
with open(filename, 'w', newline='', encoding='utf-8-sig') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print(f"🎉 Đã tạo thành công tệp '{filename}'!")
# Out:
# 🎉 Đã tạo thành công tệp 'my_words.csv'!

# %% [markdown]
# ## Step 3: 단어장 파일 읽어오기
#
# 이제 앞서 업로드한 `my_words.csv` 파일에서 단어를 읽어와 'words'라는 이름의 빈 바구니(리스트)에 담을 차례입니다.
# 코드 중간에 있는 **빈칸(`[학생 작성란]`)**을 AI와 협업하여 채워보세요!
#
# > **🤖 AI에게 물어볼 질문 예시**
# > * "파이썬에서 csv 파일을 읽으려면 `csv` 모듈의 어떤 함수를 써야 해?"
# > * "리스트에 딕셔너리 형태로 값을 추가하려면 코드를 어떻게 짜야 해?"

# %%
filename = "my_words.csv"  # 우리가 읽어올 파일의 이름입니다.
words = []                 # 단어들을 차곡차곡 담을 '빈 바구니(리스트)'를 하나 만듭니다.

try:
    # 파일을 열어서(open) f 라는 별명을 붙여줍니다. (한글이 깨지지 않게 utf-8-sig 사용)
    with open(filename, 'r', encoding='utf-8-sig') as f:
        # --------------------------------------------------------
        # [학생 작성란 1]
        # csv 도구함을 써서 파일을 한 줄씩 읽을 준비를 하는 코드를 완성하세요.
        # --------------------------------------------------------
        reader = csv.reader(f)

        # 파일의 처음부터 끝까지 한 줄씩 반복해서(for) 읽어옵니다.
        for row in reader:
            # 빈 줄이 아니라면 (데이터가 2개 이상 있다면)
            if len(row) >= 2:
                # --------------------------------------------------------
                # [학생 작성란 2]
                # '한국어'와 '뜻'이라는 이름표를 붙여서 짝을 지어(딕셔너리) words 바구니에 담으세요.
                # (힌트: append() 안에 {'한국어': ..., '뜻': ...} 형태가 들어가야 하며, strip()을 꼭 포함하세요)
                # --------------------------------------------------------
                words.append({'한국어': row[0].strip(), '뜻': row[1].strip()})

    # 파일 읽기가 끝나면 성공 메시지와 함께 총 몇 개의 단어를 담았는지 화면에 알려줍니다.
    print(f"🎉 성공! 총 {len(words)}개의 단어를 불러왔습니다.")
except FileNotFoundError:
    # 만약 파일 이름이 틀렸거나 업로드되지 않았다면 컴퓨터가 멈추는 대신 이 에러 메시지를 띄웁니다.
    print(f"⚠️ 에러: '{filename}' 파일을 찾을 수 없습니다. 왼쪽 폴더에 파일이 잘 업로드되었는지 다시 확인해 주세요!\n")
# Out:
# 🎉 성공! 총 52개의 단어를 불러왔습니다.

# %% [markdown]
# ## Step 4: 무한 퀴즈 루프 (Prompting)
#
# 단어장에서 무작위로 문제를 내고, 사용자의 정답을 검사하는 핵심 퀴즈 코드입니다.
# 하지만 코드 중간중간 **빈칸(`[학생 작성란]`)**이 뚫려 있습니다. 이 빈칸을 여러분이 직접 채워야 코드가 정상적으로 실행됩니다.
#
# 코드를 어떻게 써야 할지 막막하다면 **AI(Gemini)에게 직접 물어보세요!**
#
# > **🤖 AI에게 물어볼 질문 예시**
# > * "파이썬에서 사용자에게 화면에서 글씨를 입력받으려면 어떤 함수를 써야 해?"
# > * "파이썬에서 두 변수의 값이 완전히 똑같은지 비교하려면 if문을 어떻게 써야 해?"

# %%
# 위 셀에서 words 바구니(리스트)에 단어가 잘 들어왔는지 확인합니다.
if len(words) > 0:
    while True: # 무한히 반복해서 퀴즈를 냅니다.
        # random 도구함을 써서 단어 바구니 중 하나를 무작위로 뽑습니다.
        question = random.choice(words)
        kor_word = question['한국어'] # 뽑힌 문제의 외국어/질문 부분
        meaning = question['뜻']    # 뽑힌 문제의 정답 부분

        # 화면에 문제를 출력해줍니다.
        print(f"\n📝 문제: '{kor_word}' 의 뜻은 무엇일까요?")

        # --------------------------------------------------------
        # [학생 작성란 1]
        # 화면에 "정답을 입력하세요 ('종료' 입력시 끝남): " 라고 띄우고,
        # 사용자가 키보드로 입력한 값을 user_answer 라는 변수(공간)에 저장하세요.
        # --------------------------------------------------------
        user_answer = input("정답을 입력하세요 ('종료' 입력시 끝남): ")

        # 종료 조건: 사용자가 '종료'라고 치면 while 무한 루프를 빠져나옵니다(break).
        if user_answer == '종료':
            print("퀴즈를 마칩니다. 수고하셨습니다!")
            break

        # --------------------------------------------------------
        # [학생 작성란 2]
        # 사용자가 입력한 정답(user_answer)과 실제 뜻(meaning)이 완전히 똑같은지
        # 비교하는 조건문(if)을 완성하세요.
        # --------------------------------------------------------
        if user_answer == meaning:
            print("✅ 정답입니다! 멋져요!")
        else:
            print(f"❌ 틀렸습니다. 정답은 '{meaning}' 입니다.")
else:
    print("단어장 데이터가 없습니다. 위의 Step 3 셀을 먼저 실행해서 단어를 불러와주세요.")
# Out:
# 📝 문제: '자다' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Ngủ
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '많다' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Nhiều
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '귀엽다' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Dễ thương
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '저거' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Cái kia
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '있다' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Có
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '네' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Vâng
# ❌ 틀렸습니다. 정답은 'Vâng / Dạ' 입니다.
#
# 📝 문제: '물' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Nước
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '감사합니다' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Cảm ơn
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '말하다' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Nói
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '맛없어요' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Dở
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '한국어' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Tiếng Hàn
# ❌ 틀렸습니다. 정답은 '베트남어' 입니다.
#
# 📝 문제: '있다' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Có
# ✅ 정답입니다! 멋져요!
#
# 📝 문제: '덥다' 의 뜻은 무엇일까요?
# 정답을 입력하세요 ('종료' 입력시 끝남): Nóng
# ...

# %% [markdown]
# ## Step 5: 에러 해결하기 (Troubleshooting)
#
# 코드를 작성하고 실행(`Shift + Enter`)했는데 빨간 글씨(에러)가 쏟아진다고 당황하지 마세요! 프로그래밍에서 에러는 숨쉬는 것만큼 자연스러운 일입니다.
#
# 에러 메시지를 **마우스로 드래그해서 그대로 복사**한 뒤, Gemini에게 물어보세요.
#
# > **🤖 질문 예시:**
# > "코드를 실행했더니 이런 에러가 났어. 내가 짠 빈칸 코드 부분에 무슨 문제가 있는 거야?"
# > `(여기에 복사한 에러 메시지를 붙여넣기)`
#
# 이렇게 에러를 스스로 고쳐가며 AI와 나눈 대화 기록(채팅 링크 또는 캡처)은 **과제 제출 시 여러분의 학습을 증명하는 필수 증빙 자료**가 됩니다.

# %% [markdown]
# ## 한국어-베트남어 단어장 (CSV 형식)
#
# 아래 코드를 복사하여 `my_words.csv` 파일로 저장하거나, 직접 Colab 환경에 새 파일을 만들어 붙여넣기할 수 있습니다.
#
# ```csv
# 한국어,베트남어
# 안녕하세요,Xin chào
# 감사합니다,Cảm ơn
# 네,Vâng / Dạ
# 아니요,Không
# 죄송합니다,Xin lỗi
# 잠시만요,Khoan đã / Chờ một chút
# 사랑해요,Anh yêu em / Em yêu anh
# 좋아해요,Tôi thích bạn
# 배고파요,Tôi đói bụng
# 목말라요,Tôi khát nước
# 화장실,Nhà vệ sinh
# 물,Nước
# 커피,Cà phê
# 밥,Cơm
# 빵,Bánh mì
# 김치,Kim chi
# 비빔밥,Cơm trộn
# 맛있어요,Ngon
# 맛없어요,Dở
# 얼마예요?,Bao nhiêu tiền?
# 여기요,Ở đây (Gọi phục vụ)
# 저기요,Ở đằng kia
# 이거,Cái này
# 저거,Cái kia
# 어디,Ở đâu
# 언제,Khi nào
# 무엇,Cái gì
# 누구,Ai
# 왜,Tại sao
# 어떻게,Làm thế nào
# 예쁘다,Đẹp
# 귀엽다,Dễ thương
# 덥다,Nóng
# 춥다,Lạnh
# 좋다,Tốt / Thích
# 싫다,Không thích / Ghét
# 크다,To / Lớn
# 작다,Nhỏ
# 많다,Nhiều
# 적다,Ít
# 있다,Có
# 없다,Không có
# 가다,Đi
# 오다,Đến
# 먹다,Ăn
# 자다,Ngủ
# 공부하다,Học
# 일하다,Làm việc
# 보다,Nhìn / Xem
# 듣다,Nghe
# 말하다,Nói
# ```
